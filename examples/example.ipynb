# %%
from pytrajlib import plot, simulation

# %%
run_params = simulation.get_run_params()
run_params["num_runs"] = 10
run_params["atm_model"] = 1
run_params["atm_error"] = 0
run_params["impact_output"] = 1
run_params["traj_output"] = 0
impact_data = simulation.run(run_params)
plot.impact(run_params=run_params, data=impact_data)
# Out:
# -3246652.5824687243 5481686.602535544 0.0
# Running with aimpoint: -3246652.5824687243, 5481686.602535544, 0.0
# Trajectory output : ./output/trajectory.txt
# Range to aimpoint:  13414232.96957915
# CEP:  51.3217145439542
# Nakagami fit: shape = 1.3095547753076888 loc = 0 scale = 66.29219802610974

# %%
plot.all_trajectory_plots(run_params)
