# %%
from pytrajlib import plot, simulation

# %%
run_params = simulation.get_run_params()
run_params["num_runs"] = 100
run_params["impact_output"] = 0
run_params["traj_output"] = 2
run_params["booster_type"] = "mmiii" 
run_params["rv_maneuv"] = 0

# Overwrite run params because we pass in kwargs relevant for plotting
impact_data, run_params = simulation.run(run_params, launch_lat_lon=[-10, -30], aim_lat_lon=[42.3596, -71.092])
plot.map(run_params=run_params, data=impact_data, show_attribution=True)
# Out:
# Parsing booster type: MMIII
# Progress:   0%|          | 0/100 [00:00<?, ?it/s]
# output directory: /home/adder/Documents/lnsp/pytrajlib/examples/20250731_091014
# xaim in run params:  True
# 1525536.6300304728
# aimpont_lat: 0.73931448982779, aimpoint_lon: -1.2407894718278087
# launch_lat: -0.17453292519943292, launch_lon: -0.5235987755982988
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9efba7ad33c721a67c94c460392373be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9efba7ad33c721a67c94c460392373be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9efba7ad33c721a67c94c460392373be = L.map(
#                 &quot;map_9efba7ad33c721a67c94c460392373be&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;attributionControl&quot;: 1,
#   &quot;worldCopyJump&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9efba7ad33c721a67c94c460392373be);
#
#
#
#
#
#             var tile_layer_188c13bfeeffc3d0aea84fd818f7cce7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_188c13bfeeffc3d0aea84fd818f7cce7.addTo(map_9efba7ad33c721a67c94c460392373be);
#
#
#             var circle_f7e452cd886912b9294bb5ba668e97aa = L.circle(
#                 [42.3596, -71.092],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 24.34, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_9efba7ad33c721a67c94c460392373be);
#
#
#             circle_f7e452cd886912b9294bb5ba668e97aa.bindTooltip(
#                 `&lt;div&gt;
#                      CEP: 24.34 m
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_fe3e1a2945307741d276e7db4195611e = L.marker(
#                 [-9.999999999999998, -29.999999999999996],
#                 {
# }
#             ).addTo(map_9efba7ad33c721a67c94c460392373be);
#
#
#             marker_fe3e1a2945307741d276e7db4195611e.bindTooltip(
#                 `&lt;div&gt;
#                      Launch Point -10.00°N, -30.00°E
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_59f4ae7f25ae997bbddd07e7ed88c33c = L.marker(
#                 [42.3596, -71.092],
#                 {
# }
#             ).addTo(map_9efba7ad33c721a67c94c460392373be);
#
#
#             marker_59f4ae7f25ae997bbddd07e7ed88c33c.bindTooltip(
#                 `&lt;div&gt;
#                      Aim Point 42.36°N, -71.09°E
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5c91a80525f6c60fffaa0a2568e03e32 = L.marker(
#                 [42.35972443743244, -71.09175691962835],
#                 {
# }
#             ).addTo(map_9efba7ad33c721a67c94c460392373be);
#
#
#             var div_icon_a702fe5157b1b607ec336d5278929d7b = L.divIcon({
#   &quot;html&quot;: &quot;\n    \u003csvg width=\&quot;24\&quot; height=\&quot;24\&quot; viewBox=\&quot;0 0 32 32\&quot; xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\u003e\n        \u003cline x1=\&quot;8\&quot; y1=\&quot;8\&quot; x2=\&quot;24\&quot; y2=\&quot;24\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; stroke-linecap=\&quot;round\&quot;/\u003e\n        \u003cline x1=\&quot;24\&quot; y1=\&quot;8\&quot; x2=\&quot;8\&quot; y2=\&quot;24\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; stroke-linecap=\&quot;round\&quot;/\u003e\n    \u003c/svg\u003e\n    &quot;,
#   &quot;iconSize&quot;: [32, 32],
#   &quot;iconAnchor&quot;: [16, 16],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_5c91a80525f6c60fffaa0a2568e03e32.bindTooltip(
#                 `&lt;div&gt;
#                      Impact Point 1: 42.36°N, -71.09°E
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5c91a80525f6c60fffaa0a2568e03e32.setIcon(div_icon_a702fe5157b1b607ec336d5278929d7b);
#
#
#             var marker_955d342c5107e746d1677e192e84155e = L.marker(
#                 [42.35956091320277, -71.09185389964792],
#                 {
# }
#             ).addTo(map_9efba7ad33c721a67c94c460392373be);
#
#
#             var div_icon_1e1ab3a82861ef7bcbe7b77bdd08a152 = L.divIcon({
#   &quot;html&quot;: &quot;\n    \u003csvg width=\&quot;24\&quot; height=\&quot;24\&quot; viewBox=\&quot;0 0 32 32\&quot; xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\u003e\n        \u003cline x1=\&quot;8\&quot; y1=\&quo

# %%
plot.impact(run_params=run_params, data=impact_data)
# Out:
# Range to aimpoint:  7165532.741637251
# aimpont_lat: 0.73931448982779, aimpoint_lon: -1.2407894718278087
# launch_lat: -0.17453292519943292, launch_lon: -0.5235987755982988
# Nakagami fit: shape = 0.8889870883008515 loc = 0 scale = 32.27838091205487

# %%
plot.all_trajectory_plots(run_params)
