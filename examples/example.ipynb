# %%
from pytrajlib import plot, simulation

# %%
run_params = simulation.get_run_params()
run_params["num_runs"] = 100
run_params["impact_output"] = 0
run_params["traj_output"] = 2
run_params["booster_type"] = "mmiii" 
run_params["rv_type"] = 0
impact_data = simulation.run(run_params, launch_lat_lon=[-10, -30], aim_lat_lon=[42.3596, -71.092])
plot.map(run_params=run_params, data=impact_data, show_attribution=True)
# Out:
# Parsing booster type: MMIII
# Optimizing...
# bearing vector: 0.760250, -0.485677
# bearing angle 122.572014
# Thrust angles: theta_long: -17.205898, theta_lat: 24.845914
# aimpont_lat: 0.73931448982779, aimpoint_lon: -1.2407894718278087
# launch_lat: -0.17453292519943292, launch_lon: -0.5235987755982988
# CEP:  22.549005206253234
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27de22dab16a1c46e469f64d61570933 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27de22dab16a1c46e469f64d61570933&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27de22dab16a1c46e469f64d61570933 = L.map(
#                 &quot;map_27de22dab16a1c46e469f64d61570933&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;attributionControl&quot;: 1,
#   &quot;worldCopyJump&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_27de22dab16a1c46e469f64d61570933);
#
#
#
#
#
#             var tile_layer_2e1d55bf89a974e3bcec416c9631ddf1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e1d55bf89a974e3bcec416c9631ddf1.addTo(map_27de22dab16a1c46e469f64d61570933);
#
#
#             var circle_0a7cb87aafc499a0d9a7f3a4738ff2d7 = L.circle(
#                 [42.3596, -71.092],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.55, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_27de22dab16a1c46e469f64d61570933);
#
#
#             circle_0a7cb87aafc499a0d9a7f3a4738ff2d7.bindTooltip(
#                 `&lt;div&gt;
#                      CEP: 22.55 m
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_080a0b6728df9dff34d2e26038a60eb1 = L.marker(
#                 [-9.999999999999998, -29.999999999999996],
#                 {
# }
#             ).addTo(map_27de22dab16a1c46e469f64d61570933);
#
#
#             marker_080a0b6728df9dff34d2e26038a60eb1.bindTooltip(
#                 `&lt;div&gt;
#                      Launch Point -10.00°N, -30.00°E
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_b7bade2a307015b99c5964c4bce4fce1 = L.marker(
#                 [42.3596, -71.092],
#                 {
# }
#             ).addTo(map_27de22dab16a1c46e469f64d61570933);
#
#
#             marker_b7bade2a307015b99c5964c4bce4fce1.bindTooltip(
#                 `&lt;div&gt;
#                      Aim Point 42.36°N, -71.09°E
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_357b5024b5933ae9c1103577c328a88a = L.marker(
#                 [42.35955959780429, -71.09186579340842],
#                 {
# }
#             ).addTo(map_27de22dab16a1c46e469f64d61570933);
#
#
#             var div_icon_80fe508c6c677614c24e2e7529d31edd = L.divIcon({
#   &quot;html&quot;: &quot;\n    \u003csvg width=\&quot;24\&quot; height=\&quot;24\&quot; viewBox=\&quot;0 0 32 32\&quot; xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\u003e\n        \u003cline x1=\&quot;8\&quot; y1=\&quot;8\&quot; x2=\&quot;24\&quot; y2=\&quot;24\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; stroke-linecap=\&quot;round\&quot;/\u003e\n        \u003cline x1=\&quot;24\&quot; y1=\&quot;8\&quot; x2=\&quot;8\&quot; y2=\&quot;24\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; stroke-linecap=\&quot;round\&quot;/\u003e\n    \u003c/svg\u003e\n    &quot;,
#   &quot;iconSize&quot;: [32, 32],
#   &quot;iconAnchor&quot;: [16, 16],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_357b5024b5933ae9c1103577c328a88a.setIcon(div_icon_80fe508c6c677614c24e2e7529d31edd);
#
#
#             var marker_10fe50d2448ef6ad307b37e52f85c0d8 = L.marker(
#                 [42.359711082473275, -71.0917812272105],
#                 {
# }
#             ).addTo(map_27de22dab16a1c46e469f64d61570933);
#
#
#             var div_icon_1cf1bb0c6438ab4e3d28a31aff103510 = L.divIcon({
#   &quot;html&quot;: &quot;\n    \u003csvg width=\&quot;24\&quot; height=\&quot;24\&quot; viewBox=\&quot;0 0 32 32\&quot; xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\u003e\n        \u003cline x1=\&quot;8\&quot; y1=\&quot;8\&quot; x2=\&quot;24\&quot; y2=\&quot;24\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; stroke-linecap=\&quot;round\&quot;/\u003e\n        \u003cline x1=\&quot;24\&quot; y1=\&quot;8\&quot; x2=\&quot;8\&quot; y2=\&quot;24\&quot; stroke=\&qu

# %%
plot.impact(run_params=run_params, data=impact_data)
# Out:
# Range to aimpoint:  7165532.741637251
# aimpont_lat: 0.73931448982779, aimpoint_lon: -1.2407894718278087
# launch_lat: -0.17453292519943292, launch_lon: -0.5235987755982988
# CEP:  22.549005206253234
# Nakagami fit: shape = 0.7340235710337049 loc = 0 scale = 33.60188434876504

# %%
plot.all_trajectory_plots(run_params)
