# %%
from pytrajlib import plot, simulation

# %%
run_params = simulation.get_run_params()
run_params["num_runs"] = 100
run_params["impact_output"] = 0
run_params["traj_output"] = 2
run_params["booster_type"] = "mmiii" 
run_params["rv_type"] = 0

# Overwrite run params because we pass in kwargs relevant for plotting
impact_data, run_params = simulation.run(run_params, launch_lat_lon=[-10, -30], aim_lat_lon=[42.3596, -71.092])
plot.map(run_params=run_params, data=impact_data, show_attribution=True)
# Out:
# Parsing booster type: MMIII
# Optimizing...
# bearing vector: 0.760250, -0.485677
# bearing angle 122.572014
# Thrust angles: theta_long: -17.205898, theta_lat: 24.845914
# Progress:   0%|          | 0/300 [00:00<?, ?it/s]
# output directory: /home/adder/Documents/lnsp/pytrajlib/examples/20250702_161600
# xaim in run params:  True
# 1525536.6300304728
# Calculating local impact coordinates...
# {'run_name': 'default', 'run_type': 0, 'output_dir': '/home/adder/Documents/lnsp/pytrajlib/examples/20250702_161600', 'impact_data_path': '/home/adder/Documents/lnsp/pytrajlib/examples/20250702_161600/impact.txt', 'trajectory_path': '/home/adder/Documents/lnsp/pytrajlib/examples/20250702_161600/trajectory.txt', 'atm_profile_path': '/home/adder/Documents/lnsp/pytrajlib/src/pytrajlib/config/atmprofiles.txt', 'num_runs': 300, 'time_step_main': 1.0, 'time_step_reentry': 0.01, 'traj_output': 2, 'impact_output': 0, 'x_launch': np.float64(5433625.417069016), 'y_launch': np.float64(-3137105.0972203882), 'z_launch': np.float64(-1106312.5399160131), 'x_aim': np.float64(1525536.6300304728), 'y_aim': np.float64(-4453698.585795378), 'z_aim': np.float64(4292662.099131438), 'theta_long': 1.04719755, 'theta_lat': 0.0, 'grav_error': 1, 'atm_model': 0, 'atm_error': 1, 'gnss_nav': 0, 'ins_nav': 1, 'rv_maneuv': 0, 'reentry_vel': 7500, 'deflection_time': 0.0, 'booster_type': 0, 'rv_type': 0, 'initial_x_error': 0.0, 'initial_pos_error': 0.1, 'initial_vel_error': 0.001, 'initial_angle_error': 1e-06, 'acc_scale_stability': 1e-06, 'gyro_bias_stability': 1e-08, 'gyro_noise': 1e-08, 'gnss_noise': 0.0, 'cl_pert': 0.0, 'step_acc_mag': 0.0, 'step_acc_hgt': 0.0, 'step_acc_dur': 0.0, 'launch_lat_lon': [-10, -30], 'aim_lat_lon': [42.3596, -71.092]}
# x_aim:  1525536.6300304728
# aimpont_lat: 0.73931448982779, aimpoint_lon: -1.2407894718278087
# launch_lat: -0.17453292519943292, launch_lon: -0.5235987755982988
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b00ecef3e2db794558abc9a5fbace895 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b00ecef3e2db794558abc9a5fbace895&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b00ecef3e2db794558abc9a5fbace895 = L.map(
#                 &quot;map_b00ecef3e2db794558abc9a5fbace895&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;attributionControl&quot;: 1,
#   &quot;worldCopyJump&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b00ecef3e2db794558abc9a5fbace895);
#
#
#
#
#
#             var tile_layer_90951cd42bbbfb95b814bbeb33bb5d6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90951cd42bbbfb95b814bbeb33bb5d6e.addTo(map_b00ecef3e2db794558abc9a5fbace895);
#
#
#             var circle_addfc45200abff1e97c950ad67d7e817 = L.circle(
#                 [42.3596, -71.092],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 26.21, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_b00ecef3e2db794558abc9a5fbace895);
#
#
#             circle_addfc45200abff1e97c950ad67d7e817.bindTooltip(
#                 `&lt;div&gt;
#                      CEP: 26.21 m
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1351de3857c51dc34776edc52293a3ea = L.marker(
#                 [-9.999999999999998, -29.999999999999996],
#                 {
# }
#             ).addTo(map_b00ecef3e2db794558abc9a5fbace895);
#
#
#             marker_1351de3857c51dc34776edc52293a3ea.bindTooltip(
#                 `&lt;div&gt;
#                      Launch Point -10.00°N, -30.00°E
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_678fab7cde2cf22120a1c64514fb9ed8 = L.marker(
#                 [42.3596, -71.092],
#                 {
# }
#             ).addTo(map_b00ecef3e2db794558abc9a5fbace895);
#
#
#             marker_678fab7cde2cf22120a1c64514fb9ed8.bindTooltip(
#                 `&lt;div&gt;
#                      Aim Point 42.36°N, -71.09°E
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c9b3fdc693a96a0b74fdb1d47061389b = L.marker(
#                 [42.35960159601813, -71.09204878707567],
#                 {
# }
#             ).addTo(map_b00ecef3e2db794558abc9a5fbace895);
#
#
#             var div_icon_4f1f82065590c4513d46dc17f9c43efe = L.divIcon({
#   &quot;html&quot;: &quot;\n    \u003csvg width=\&quot;24\&quot; height=\&quot;24\&quot; viewBox=\&quot;0 0 32 32\&quot; xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\u003e\n        \u003cline x1=\&quot;8\&quot; y1=\&quot;8\&quot; x2=\&quot;24\&quot; y2=\&quot;24\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; stroke-linecap=\&quot;round\&quot;/\u003e\n        \u003cline x1=\&quot;24\&quot; y1=\&quot;8\&quot; x2=\&quot;8\&quot; y2=\&quot;24\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; stroke-linecap=\&quot;round\&quot;/\u003e\n    \u003c/svg\u003e\n    &quot;,
#   &quot;iconSize&quot;: [32, 32],
#   &quot;iconAnchor&quot;: [16, 16],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_c9b3fdc693a96a0b74fdb1d47061389b.setIcon(div_icon_4f1f82065590c4513d46dc17f9c43efe);
#
#
#             var marker_c2532ba6c6f99c3be1785e49f679239f = L.marker(
#                 [42.35973007689454, -71.09225536461476],
#                 {
# }
#             ).addTo(map_b00ecef3e2db794558abc9a5fbace895);
#
#
#             var div_icon_1d42c303d6c4ab16aa0fd22a45ab4ac4 = L.divIcon({
#   &quot;html&quot;: &quot;\n    \u003csvg width=\&quot;24\&quot; height=\&quot;24\&quot; viewBox=\&quot;0 0 32 32\&quot; xmlns=\&quot;http://www.w3.org/2000/svg\&quot;\u003e\n        \u003cline x1=\&quot;8\&quot; y1=\&quot;8\&quot; x2=\&quot;24\&quot; y2=\&quot;24\&quot; stroke=\&quot;black\&quot; stroke-width=\&quot;3\&quot; stroke-linecap=\&quot;round\&quot;/\u003e\n        \u003cline x1=\&quot;24\&quot; y1=\&quot;8\&quot; x2=\&quot;8\&quot; y2=\&quot;24\&quot; stroke=\&qu

# %%
plot.impact(run_params=run_params, data=impact_data)
# Out:
# Range to aimpoint:  7165532.741637251
# aimpont_lat: 0.73931448982779, aimpoint_lon: -1.2407894718278087
# launch_lat: -0.17453292519943292, launch_lon: -0.5235987755982988
# CEP:  22.549005206253234
# Nakagami fit: shape = 0.7340235710337049 loc = 0 scale = 33.60188434876504

# %%
plot.all_trajectory_plots(run_params)
